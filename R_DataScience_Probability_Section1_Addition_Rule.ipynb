# %%
install.packages("gtools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(gtools)

# %%
#Section 1: Discrete Probability/1.3 Addition Rule and Monty Hall
#Pr(A or B) = Pr(A) + Pr(B) - Pr(A and B)
#The addition rule for a natural 21 in blackjack
Pr_Ace = 4/52
Pr_Face = 16/52

# %%
Pr_Ace_Face = 4/52 * 16/51 #Pr of Ace and Face
Pr_Face_Ace = 16/52 * 4/51 #Pr of Face and Ace

# %%
Pr_Ace_Face_OR_Pr_Face_Ace = Pr_Ace_Face + Pr_Face_Ace

# %%
suits <- c("Diamonds", "Clubs", "Hearts", "Spades")
numbers <- c("Ace", "Deuce", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine", "Ten", "Jack", "Queen", "King")
deck <- expand.grid(number = numbers, suit = suits)
deck <- paste(deck$number, deck$suit)
deck
# Out:
#  [1] "Ace Diamonds"   "Deuce Diamonds" "Three Diamonds" "Four Diamonds"
#  [5] "Five Diamonds"  "Six Diamonds"   "Seven Diamonds" "Eight Diamonds"
#  [9] "Nine Diamonds"  "Ten Diamonds"   "Jack Diamonds"  "Queen Diamonds"
# [13] "King Diamonds"  "Ace Clubs"      "Deuce Clubs"    "Three Clubs"
# [17] "Four Clubs"     "Five Clubs"     "Six Clubs"      "Seven Clubs"
# [21] "Eight Clubs"    "Nine Clubs"     "Ten Clubs"      "Jack Clubs"
# [25] "Queen Clubs"    "King Clubs"     "Ace Hearts"     "Deuce Hearts"
# [29] "Three Hearts"   "Four Hearts"    "Five Hearts"    "Six Hearts"
# [33] "Seven Hearts"   "Eight Hearts"   "Nine Hearts"    "Ten Hearts"
# [37] "Jack Hearts"    "Queen Hearts"   "King Hearts"    "Ace Spades"
# [41] "Deuce Spades"   "Three Spades"   "Four Spades"    "Five Spades"
# [45] "Six Spades"     "Seven Spades"   "Eight Spades"   "Nine Spades"
# [49] "Ten Spades"     "Jack Spades"    "Queen Spades"   "King Spades"

# %%
hands <- permutations(52,2, v = deck)
hands
# Out:
#       [,1]         [,2]
#  [1,] Ace Clubs    Ace Diamonds
#  [2,] Ace Clubs    Ace Hearts
#  [3,] Ace Clubs    Ace Spades
#  [4,] Ace Clubs    Deuce Clubs
#  [5,] Ace Clubs    Deuce Diamonds
#  [6,] Ace Clubs    Deuce Hearts
#  [7,] Ace Clubs    Deuce Spades
#  [8,] Ace Clubs    Eight Clubs
#  [9,] Ace Clubs    Eight Diamonds
# [10,] Ace Clubs    Eight Hearts
# [11,] Ace Clubs    Eight Spades
# [12,] Ace Clubs    Five Clubs
# [13,] Ace Clubs    Five Diamonds
# [14,] Ace Clubs    Five Hearts
# [15,] Ace Clubs    Five Spades
# [16,] Ace Clubs    Four Clubs
# [17,] Ace Clubs    Four Diamonds
# [18,] Ace Clubs    Four Hearts
# [19,] Ace Clubs    Four Spades
# [20,] Ace Clubs    Jack Clubs
# [21,] Ace Clubs    Jack Diamonds
# [22,] Ace Clubs    Jack Hearts
# [23,] Ace Clubs    Jack Spades
# [24,] Ace Clubs    King Clubs
# [25,] Ace Clubs    King Diamonds
# [26,] Ace Clubs    King Hearts
# [27,] Ace Clubs    King Spades
# [28,] Ace Clubs    Nine Clubs
# [29,] Ace Clubs    Nine Diamonds
# ...

# %%
aces <- paste("Ace", suits)
facecard <- c("King", "Queen", "Jack", "Ten")
facecard <- expand.grid(number = facecard, suit = suits)
facecard <- paste(facecard$number, facecard$suit)

# %%
mean(hands[,1] %in% aces)
# Out:
# [1] 0.07692308

# %%
mean(hands[,2] %in% facecard)
# Out:
# [1] 0.3076923

# %%
# probability of a natural 21 given that the ace is listed first in `combinations`
mean(hands[,1] %in% aces & hands[,2] %in% facecard)
# Out:
# [1] 0.02413273

# %%
mean(hands[,1] %in% facecard & hands[,2] %in% aces)
# Out:
# [1] 0.02413273

# %%
mean((hands[,1] %in% aces & hands[,2] %in% facecard) | (hands[,1] %in% facecard & hands[,2] %in% aces))
# Out:
# [1] 0.04826546
